# %% [markdown]
# # More Flow Control
#
# Term 1 2019 - Instructor: Teerapong Leelanupab
#
# Teaching Assistant: Suttida Satjasunsern
#
# - - -

# %% [markdown]
# ### If statements
#
# These statements select code to execute based on the value of a specified boolean expression - i.e. is the expression True or False. The simplest form has just one condition after the _if_ keyword. The subsequent code block will be executed if that conditions is True, otherwise it will be skipped.

# %%
x = 3 
y = 4
if x < y:
    print("y is greater")    # code block

# %% [markdown]
# We can also include the _elif_ keyword with an alternative condition. If the first condition is False and the second condition is True, the second code block will be executed:

# %%
a = 5 
b = 5
if a > b:
    print("a is greater")      # first code block
elif a == b:
    print("values are equal")  # alternative code block

# %% [markdown]
# We can also add a &quot;last resort&quot; code block after the _else_ keyword, which is executed if none of the previous conditions evaluate to True:

# %%
v = 9
w = 10
if v > w:
    print("v is greater")      # first branch
elif v == w:
    print("both values are equal")  # alternative branch
else: 
    print("last resort, w must be greater")      # last resort

# %% [markdown]
# ### While Loops

# %% [markdown]
# While loops repeatedly execute a block of code as long as a specified Boolean expression remains True.

# %%
x = 5
while x < 10:                    # header line with condition
    print("x is currently", x)   # code block
    x = x + 1

# %% [markdown]
# If the condition never holds True, then the code block will never be executed:

# %%
y = 10
while y < 4:
    print(y)    # this code block will not be executed

# %% [markdown]
# A number of special keywords can alter the execution of a while loop. Most commonly, the _break_ keyword &quot;breaks out&quot; of the loop, so that the block of code is no longer executed.

# %%
z = 1
while z < 8:
    print("z is",z)
    if z%3 == 0:
        print("breaking out of loop when z is",z)
        break
    z += 1

# %% [markdown]
# ### For loops

# %% [markdown]
# For loops iterate over a sequence and repeatedly apply a block of code to each item in the sequence. They can be applied to the items in any ordered sequence or other iterable object - e.g. a list, a tuple, a set, or the output of a function.

# %%
vals = [2.5, 4.2, 3.1, 6.7, 8.9]
for v in vals:
    print(v)

# %% [markdown]
# Items in the sequence being iterated over can have any type:

# %%
mylist = ["KMITL",2020,True,0.0123]
for x in mylist:
    print("Next item is",x)

# %% [markdown]
# Iterating over a _set_ is the same as iterating over a list with a _for_ loop:

# %%
countries = set(["Ireland","France","Germany","Italy"])
for country in countries:
    print(country)

# %% [markdown]
# We can also easily iterate over the keys in a dictionary using a _for_ loop:

# %%
capitals = { "Italy":"Rome", "Ireland":"Dublin", "Germany":"Berlin" }
for country in capitals:
    print(country, "=", capitals[country])

# %% [markdown]
# **Numeric Ranges**: To iterate over a sequence of numbers, the built-in function _range()_ is frequently used to generate arithmetic integer sequences. It can be used in several different ways:

# %%
# Iterate over a sequence starting at 0 and ending before 4:
for i in range(4):
    print(i)

# %%
# Iterate over a sequence starting at 3 and ending before 8:
for i in range(3,8):
    print(i)

# %%
# Iterate over a sequence starting at 5, ending before 20, and incrementing by 4 at each step:
for i in range(5,20,4):
    print(i)

# %% [markdown]
# We can also include a negative step size, where we start at a larger number and end before a smaller number.

# %%
# Start at 40, ending before 20, and decrementing by 5 each time (i.e adding -5):
for i in range(40,20,-5):
    print(i)

# %% [markdown]
# Note that the output of _range()_ is not actually a list. If we want to convert it to one, we need to call the _list()_ function:

# %%
list(range(5,20,4))
